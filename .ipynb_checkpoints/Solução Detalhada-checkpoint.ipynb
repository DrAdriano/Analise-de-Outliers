# %% [markdown]
# # Análise de Dados Imobiliários
#
# Este repositório contém uma solução para um desafio envolvendo análise de dados e é organizado de maneira detalhada e acessível, podendo ser entendida por quem é iniciante na linguagem Python, principalmente se tiver familiaridade com a biblioteca Pandas.
#
# **Desafio:** Analisar, usando Python, os dados de uma empresa de imóveis e fazer o devido tratamento de dados, principalmente para os inúmeros valores nulos. O foco da análise são os imóveis residenciais, um subconjunto da base de dados original, em que deve ser realizada a seguintes tarefas: (1) Cálculo do valor bruto para morar em cada imóvel; (2) Cálculo do valor do metro quadrado de cada imóvel; (3) Contar a quantidade de imóveis que possuem de até 2 quartos, depois 3 e 4 quartos, 5 e 6 e a faixa final de 7 ou mais quartos; (4) Cálculo dos valores estatísticos descritivos do aluguel por bairro; (5) Usando o Box Plot, remover os outliers, ou seja, os imóveis com valores muito discrepantes dos outros do bairro.
#
# Estão disponibilizados neste [repositório](https://github.com/DrAdriano/Analise-de-dados-imobiliarios) os seguintes arquivos: a base de dados, que contém informações de aproximadamente 33.000 imóveis; e a solução detalhada, em que estão explicações de como foram desenvolvidas ideias.
#
# ## Sumário
#
# 1. Bibliotecas usadas
# 2. Passo a passo do código
#     * 2.1 Importando a base de dados
#     * 2.2 Visualizando a base de dados
#         * 2.2.1 Mostrando os tipos de dados
#         * 2.2.2 Mostrando os tipos de imóveis
#         * 2.2.3 Identificando os imóveis residenciais
#     * 2.3 Tratar os dados
#         * 2.3.1 Excluindo colunas desnecessárias
#         * 2.3.2 Tratando valores nulos do aluguel
#         * 2.3.3 Tratando valores nulos do condomínio
#     * 2.4 Resolvendo as tarefas
#         * 2.4.1 Fazendo o cálculo do valor bruto
#         * 2.4.2 Fazendo o cálculo do valor do metro quadrado
#         * 2.4.3 Contando a quantidade de imóveis com certas quantidades de quartos
#         * 2.4.4 Fazendo o cálculo dos valores estatísticos descritivos do aluguel
#         * 2.4.5 Removendo os outliers
# 3. Conclusões
#
# ## 1. Bibliotecas usadas
#
# As principais bibliotecas usadas: [Pandas](https://pandas.pydata.org/), pois estamos trabalhando com base de dados e sua manipulação e [Matplotlib Pyplot](https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html), para fazer a construção de gráficos. Não é necesssário instalar nenhum deles, o Jupyter já as tem naturalmente.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Passo a passo do código
#
#
# Vamos começar organizando o passo a passo do código, ou seja, a lógica de programação. Dessa maneira, temos:
#
# * Passo 1: Importar a base de dados
# * Passo 2: Visualizar a base de dados
#     * 2.1 Mostrar os tipos de dados
#     * 2.2 Mostrar os tipos de imóveis
#     * 2.3 Identificar os imóveis residenciais
# * Passo 3: Tratar os dados
#     * 3.1 Excluir colunas desnecessárias
#     * 3.2 Tratar valores nulos do aluguel
#     * 3.3 Tratar valores nulos do condomínio
# * Passo 4: Resolver as tarefas
#      * 4.1 Fazer o cálculo do valor bruto para morar em cada imóvel
#      * 4.2 Fazer o cálculo do valor do metro quadrado de cada imóvel
#      * 4.3 Contar a quantidade de imóveis com as quantidades de quartos
#      * 4.4 Fazer o cálculo do valor médio do aluguel por bairro
#      * 4.5 Remover os outliers
#
# ### 2.1 Importando a base de dados
# Importamos o arquivo, que está localizado na mesma pasta que está esse Jupyter Notebook. Adicionamos no comando que o separador de itens é o ponto e vírgula.

# %%
dados = pd.read_csv('Base de dados de imóveis.csv', sep = ';')

# %% [markdown]
# ### 2.2 Visualizando a base de dados
# Nessa etapa, vamos imprimir a tabela para entendermos como estão organizados os dados, quais informações estão disponíveis e ter um direcionamento para o tratamento de dados. Perceba que, ao importar uma tabela para o Python, usando o Pandas, ela se torna um Data Frame.

# %%
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area  Aluguel  Condominio    IPTU
# 0        40   1700.0       500.0    60.0
# 1       100   7000.0         NaN     NaN
# 2       150   5200.0      4020.0  1111.0
# 3        15    800.0       390.0    20.0
# 4        48    800.0       230.0     NaN
# ...     ...      ...         ...     ...
# 32955    27    800.0       350.0    25.0
# 32956    78   1800.0       800.0    40.0
# 32957    48   1400.0       509.0    37.0
# 32958    70   3000.0       760.0     NaN
# 32959   250   6500.0      4206.0  1109.0
#
# [32960 rows x 9 columns]

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.shape
# Out:
# (32960, 9)

# %%
print('A base de dados apresenta {} registros de imóveis e {} colunas com informações sobre os mesmos.'.format(dados.shape[0], dados.shape[1]))
# Out:
# A base de dados apresenta 32960 registros de imóveis e 9 colunas com informações sobre os mesmos.

# %% [markdown]
# #### 2.2.1 Mostrando os tipos de dados
#
# Vamos começar usando a função "dados.info()", que retornar a quantidade de valores não nulos e o tipo de variável em cada coluna, mas o nosso foco é na segunda coluna de informação.

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Aluguel     32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dados.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Aluguel       float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
tipos_de_dados = pd.DataFrame(dados.dtypes, columns = ['Tipos de Dados'])
tipos_de_dados.columns.name = 'Variáveis'
tipos_de_dados
# Out:
# Variáveis  Tipos de Dados
# Tipo               object
# Bairro             object
# Quartos             int64
# Vagas               int64
# Suites              int64
# Area                int64
# Aluguel           float64
# Condominio        float64
# IPTU              float64

# %% [markdown]
# #### 2.2.2 Mostrando os tipos de imóveis
#
# Há diferentes maneiras de mostrar os tipos de imóveis da base de dados, vamos mostrar uma que deixa a tabela organizada.

# %%
# Mostrando a coluna do tipo de imóveis.
dados['Tipo']
# Um maneira alternativa é usar: "dados.Tipo"
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
tipo_de_imovel = dados['Tipo']

# %%
type(tipo_de_imovel)
# Uma coluna de um Data Frame é uma Série.
# Out:
# pandas.core.series.Series

# %%
# Comando para deixar apenas o primeiro tipo de cada imóvel.
tipo_de_imovel.drop_duplicates()
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %%
# Entretanto, para salvar essa configuração, é preciso o "inplace = True".
tipo_de_imovel
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
tipo_de_imovel.drop_duplicates(inplace = True)
tipo_de_imovel
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %%
# Deixando os dados mais bonitos. 
tipo_de_imovel = pd.DataFrame(tipo_de_imovel)
tipo_de_imovel
# Out:
#                               Tipo
# 0                        Quitinete
# 1                             Casa
# 2          Conjunto Comercial/Sala
# 3                      Apartamento
# 7               Casa de Condomínio
# 16                  Prédio Inteiro
# 17                            Flat
# 29                      Loja/Salão
# 80         Galpão/Depósito/Armazém
# 83                  Casa Comercial
# 117                   Casa de Vila
# 159                 Terreno Padrão
# 207                    Box/Garagem
# 347                           Loft
# 589    Loja Shopping/ Ct Comercial
# 2157                       Chácara
# 3354         Loteamento/Condomínio
# 4379                         Sítio
# 4721                 Pousada/Chalé
# 6983                        Studio
# 9687                         Hotel
# 23614                    Indústria

# %%
# Perceba que os números dos índice contunuam sendo os da Base de Dados original, 
# mas podemos alterar isso.
tipo_de_imovel.index
# Out:
# Int64Index([    0,     1,     2,     3,     7,    16,    17,    29,    80,
#                83,   117,   159,   207,   347,   589,  2157,  3354,  4379,
#              4721,  6983,  9687, 23614],
#            dtype='int64')

# %%
print(f'Há {tipo_de_imovel.shape[0]} tipos de imóveis.')
# Out:
# Há 22 tipos de imóveis.

# %%
range(tipo_de_imovel.shape[0])
# Out:
# range(0, 22)

# %%
tipo_de_imovel.index = range(tipo_de_imovel.shape[0])

# %%
tipo_de_imovel.index
# Out:
# RangeIndex(start=0, stop=22, step=1)

# %%
tipo_de_imovel
# Out:
#                            Tipo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %%
# Colocando título na coluna dos índices.
tipo_de_imovel.columns.name = 'Id'
tipo_de_imovel
# Out:
# Id                         Tipo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %% [markdown]
# #### 2.2.3 Identificando os imóveis residenciais
#
# Nessa seção, vou começar organizando uma tabela apenas com os imóveis residenciais, ou seja, observando a tabela "tipo_de_imovel", vamos selecionar apenas os que são dos tipos Quitinete, Casa, Apartamento, Casa de Condomínio e Casa de Vila.

# %%
list(dados['Tipo'].drop_duplicates())
# Out:
# ['Quitinete',
#  'Casa',
#  'Conjunto Comercial/Sala',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Prédio Inteiro',
#  'Flat',
#  'Loja/Salão',
#  'Galpão/Depósito/Armazém',
#  'Casa Comercial',
#  'Casa de Vila',
#  'Terreno Padrão',
#  'Box/Garagem',
#  'Loft',
#  'Loja Shopping/ Ct Comercial',
#  'Chácara',
#  'Loteamento/Condomínio',
#  'Sítio',
#  'Pousada/Chalé',
#  'Studio',
#  'Hotel',
#  'Indústria']

# %%
residencial = ['Quitinete',
 'Casa',
 'Apartamento',
 'Casa de Condomínio',
 'Casa de Vila']

# %%
selecao = dados['Tipo'].isin(residencial)
# A função "isin()" verifica quais elementos de uma tabela estão contidos em uma lista.
# Cria uma série booleana, ou seja, com valores "True" ou "False".
selecao
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 32955     True
# 32956     True
# 32957     True
# 32958     True
# 32959    False
# Name: Tipo, Length: 32960, dtype: bool

# %%
dados_residenciais = dados[selecao]
dados_residenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#        Aluguel  Condominio  IPTU
# 0       1700.0       500.0  60.0
# 1       7000.0         NaN   NaN
# 3        800.0       390.0  20.0
# 4        800.0       230.0   NaN
# 5       1200.0         NaN   NaN
# ...        ...         ...   ...
# 32953    900.0       490.0  48.0
# 32955    800.0       350.0  25.0
# 32956   1800.0       800.0  40.0
# 32957   1400.0       509.0  37.0
# 32958   3000.0       760.0   NaN
#
# [22580 rows x 9 columns]

# %%
list(dados_residenciais['Tipo'].drop_duplicates())
# Assim verificamos quais os elementos contidos na atual coluna dos tipo de imóveis.
# Out:
# ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Casa de Vila']

# %%
print(f'Temos {dados_residenciais.shape[0]} imóveis residenciais, dentre os {dados.shape[0]} imóveis totais.')
# Out:
# Temos 22580 imóveis residenciais, dentre os 32960 imóveis totais.

# %%
dados_residenciais.index = range(dados_residenciais.shape[0])
# Renumerando os índices, siminar ao que fizemos na seção passada.
dados_residenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#        Aluguel  Condominio  IPTU
# 0       1700.0       500.0  60.0
# 1       7000.0         NaN   NaN
# 2        800.0       390.0  20.0
# 3        800.0       230.0   NaN
# 4       1200.0         NaN   NaN
# ...        ...         ...   ...
# 22575    900.0       490.0  48.0
# 22576    800.0       350.0  25.0
# 22577   1800.0       800.0  40.0
# 22578   1400.0       509.0  37.0
# 22579   3000.0       760.0   NaN
#
# [22580 rows x 9 columns]

# %%
dados_residenciais.to_csv('Arquivos gerados no código/Base de dados de imóveis residenciais.csv', sep = ';', index = False)
# Exportando a nova base de dados, que contem apenas os imóveis residenciais.

# %% [markdown]
# ### 2.3 Tratando os dados
#
# Voltamos a usar a função ".info()", agora com o foco nos números não nulos. Outras funções importantes são: ".isnull()" que reconstroí a tabela com valores boleanos, ou seja, "True" para os dados nulos e "False" para os não nulos e, sua antítese, ".notnull()".

# %%
dados_residenciais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22580 entries, 0 to 22579
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22580 non-null  object
#  1   Bairro      22580 non-null  object
#  2   Quartos     22580 non-null  int64
#  3   Vagas       22580 non-null  int64
#  4   Suites      22580 non-null  int64
#  5   Area        22580 non-null  int64
#  6   Aluguel     22571 non-null  float64
#  7   Condominio  20765 non-null  float64
#  8   IPTU        15795 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.6+ MB

# %%
dados_residenciais.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Aluguel  Condominio  \
# 0      False   False    False  False   False  False    False       False
# 1      False   False    False  False   False  False    False        True
# 2      False   False    False  False   False  False    False       False
# 3      False   False    False  False   False  False    False       False
# 4      False   False    False  False   False  False    False        True
# ...      ...     ...      ...    ...     ...    ...      ...         ...
# 22575  False   False    False  False   False  False    False       False
# 22576  False   False    False  False   False  False    False       False
# 22577  False   False    False  False   False  False    False       False
# 22578  False   False    False  False   False  False    False       False
# 22579  False   False    False  False   False  False    False       False
#
#         IPTU
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
# ...      ...
# 22575  False
# 22576  False
# 22577  False
# 22578  False
# 22579   True
#
# [22580 rows x 9 columns]

# %%
dados_residenciais.notnull()
# Out:
#        Tipo  Bairro  Quartos  Vagas  Suites  Area  Aluguel  Condominio   IPTU
# 0      True    True     True   True    True  True     True        True   True
# 1      True    True     True   True    True  True     True       False  False
# 2      True    True     True   True    True  True     True        True   True
# 3      True    True     True   True    True  True     True        True  False
# 4      True    True     True   True    True  True     True       False  False
# ...     ...     ...      ...    ...     ...   ...      ...         ...    ...
# 22575  True    True     True   True    True  True     True        True   True
# 22576  True    True     True   True    True  True     True        True   True
# 22577  True    True     True   True    True  True     True        True   True
# 22578  True    True     True   True    True  True     True        True   True
# 22579  True    True     True   True    True  True     True        True  False
#
# [22580 rows x 9 columns]

# %% [markdown]
# #### 2.3.1 Excluindo colunas desnecessárias
#
# Para a análise, não são necessárias as colunas "Vagas", "Suites" e "IPTU". O IPTU é um imposto para o dono do imóvel, não para o locatário, por isso não incluímos para o cálculo de nenhuma variável, como para o valor bruto, por exemplo.

# %%
dados_residenciais = dados_residenciais.drop(["Vagas", "Suites", "IPTU"], axis=1)
dados_residenciais
# Out:
#               Tipo                Bairro  Quartos  Area  Aluguel  Condominio
# 0        Quitinete            Copacabana        1    40   1700.0       500.0
# 1             Casa       Jardim Botânico        2   100   7000.0         NaN
# 2      Apartamento                Centro        1    15    800.0       390.0
# 3      Apartamento          Higienópolis        1    48    800.0       230.0
# 4      Apartamento          Vista Alegre        3    70   1200.0         NaN
# ...            ...                   ...      ...   ...      ...         ...
# 22575  Apartamento                 Méier        2    70    900.0       490.0
# 22576    Quitinete                Centro        0    27    800.0       350.0
# 22577  Apartamento           Jacarepaguá        3    78   1800.0       800.0
# 22578  Apartamento  São Francisco Xavier        2    48   1400.0       509.0
# 22579  Apartamento                Leblon        2    70   3000.0       760.0
#
# [22580 rows x 6 columns]

# %% [markdown]
# #### 2.3.2 Tratando valores nulos do aluguel
#
# O valor mais importante da tabela é o aluguel, esse é um número essencial para chegar nos resultados desejados.

# %%
# Verificando os imóveis com valores nulos.
dados_residenciais[dados_residenciais['Aluguel'].isnull()]
# Out:
#              Tipo           Bairro  Quartos  Area  Aluguel  Condominio
# 58    Apartamento  Barra da Tijuca        2    70      NaN       970.0
# 1492  Apartamento             Leme        2    75      NaN       878.0
# 1683         Casa     Campo Grande        3   363      NaN         NaN
# 2012  Apartamento         Botafogo        2    95      NaN      1010.0
# 2034  Apartamento       Copacabana        2    72      NaN       850.0
# 4941         Casa     Campo Grande        3   100      NaN         NaN
# 8568  Apartamento             Leme        2    75      NaN       878.0
# 8947  Apartamento           Glória        3   135      NaN       910.0
# 9149  Apartamento            Gávea        3   105      NaN       880.0

# %%
print(f"Existem {dados_residenciais[dados_residenciais['Aluguel'].isnull()].shape[0]} imóveis com valores nulos.")
# Out:
# Existem 9 imóveis com valores nulos.

# %%
# Podemos excluir os valores nulos, pois são poucos. 
dados_residenciais.dropna(subset = ['Aluguel'], inplace = True)
dados_residenciais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22571 entries, 0 to 22579
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22571 non-null  object
#  1   Bairro      22571 non-null  object
#  2   Quartos     22571 non-null  int64
#  3   Area        22571 non-null  int64
#  4   Aluguel     22571 non-null  float64
#  5   Condominio  20758 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.2+ MB

# %% [markdown]
# #### 2.3.3 Tratando valores nulos do aluguel

# %%
dados_residenciais[dados_residenciais['Condominio'].isnull()]
# Out:
#                      Tipo                    Bairro  Quartos  Area  Aluguel  \
# 1                    Casa           Jardim Botânico        2   100   7000.0
# 4             Apartamento              Vista Alegre        3    70   1200.0
# 6      Casa de Condomínio           Barra da Tijuca        5   750  22000.0
# 7      Casa de Condomínio                     Ramos        2    65   1000.0
# 8             Apartamento                    Centro        1    36   1200.0
# ...                   ...                       ...      ...   ...      ...
# 22510                Casa              Campo Grande        1    50    600.0
# 22516        Casa de Vila                    Pavuna        2    55    600.0
# 22535                Casa  Recreio dos Bandeirantes        4   352   6500.0
# 22547                Casa             Bento Ribeiro        2    60   1400.0
# 22558                Casa                    Centro        5   160   5000.0
#
#        Condominio
# 1             NaN
# 4             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# ...           ...
# 22510         NaN
# 22516         NaN
# 22535         NaN
# 22547         NaN
# 22558         NaN
#
# [1813 rows x 6 columns]

# %%
print(f"Existem {dados_residenciais[dados_residenciais['Condominio'].isnull()].shape[0]} imóveis com condomínios nulos.")
# Out:
# Existem 1813 imóveis com condomínios nulos.

# %%
# Apenas Apartamentos, Quitinetes e Casa de Condomínios costumam ter custo de condomínio,
# então vamos retirar os que estão com valores nulos.
# Começamos organizando uma seleção desses dados.
selecao = (
            ((dados_residenciais['Tipo'] == 'Apartamento') | 
             (dados_residenciais['Tipo'] == 'Quitinete') | 
             (dados_residenciais['Tipo'] == 'Casa de Condomínio')) 
            & dados_residenciais['Condominio'].isnull()
          )
selecao
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 22575    False
# 22576    False
# 22577    False
# 22578    False
# 22579    False
# Length: 22571, dtype: bool

# %%
# O "~" inverte os valores booleanos
# É necessária pois o comando abaixo retiram os que tiverem valor "False".
dados_residenciais = dados_residenciais[~selecao]
dados_residenciais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21667 entries, 0 to 22579
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        21667 non-null  object
#  1   Bairro      21667 non-null  object
#  2   Quartos     21667 non-null  int64
#  3   Area        21667 non-null  int64
#  4   Aluguel     21667 non-null  float64
#  5   Condominio  20758 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.2+ MB

# %%
print(f"Agora, existem {dados_residenciais[dados_residenciais['Condominio'].isnull()].shape[0]} imóveis com condomínios nulos, todos sendo casas.")
# Out:
# Agora, existem 909 imóveis com condomínios nulos, todos sendo casas.

# %%
# Como casas normalmente não tem valores de condomínio, atribuímos o valor zero.
dados_residenciais = dados_residenciais.fillna({'Condominio': 0})
dados_residenciais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21667 entries, 0 to 22579
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        21667 non-null  object
#  1   Bairro      21667 non-null  object
#  2   Quartos     21667 non-null  int64
#  3   Area        21667 non-null  int64
#  4   Aluguel     21667 non-null  float64
#  5   Condominio  21667 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.2+ MB

# %%
# Correção dos índices, similar ao que fizemos anteriormente.
dados_residenciais.index = range(dados_residenciais.shape[0])
dados_residenciais
# Out:
#               Tipo                Bairro  Quartos  Area  Aluguel  Condominio
# 0        Quitinete            Copacabana        1    40   1700.0       500.0
# 1             Casa       Jardim Botânico        2   100   7000.0         0.0
# 2      Apartamento                Centro        1    15    800.0       390.0
# 3      Apartamento          Higienópolis        1    48    800.0       230.0
# 4      Apartamento              Cachambi        2    50   1300.0       301.0
# ...            ...                   ...      ...   ...      ...         ...
# 21662  Apartamento                 Méier        2    70    900.0       490.0
# 21663    Quitinete                Centro        0    27    800.0       350.0
# 21664  Apartamento           Jacarepaguá        3    78   1800.0       800.0
# 21665  Apartamento  São Francisco Xavier        2    48   1400.0       509.0
# 21666  Apartamento                Leblon        2    70   3000.0       760.0
#
# [21667 rows x 6 columns]

# %% [markdown]
# ### 2.4 Resolvendo as tarefas
#
# Essa seção é destinada à resolução das tarefas, em que é necessário alguns conceitos da análise de dados e de estatística.
#
# #### 2.4.1 Fazendo o cálculo do valor bruto
#
# Para chegar no valor bruto, basta somar o valor do aluguel e o do condomínio.

# %%
dados_residenciais['Valor Bruto'] = dados_residenciais['Aluguel'] + dados_residenciais['Condominio']
dados_residenciais
# Out:
#               Tipo                Bairro  Quartos  Area  Aluguel  Condominio  \
# 0        Quitinete            Copacabana        1    40   1700.0       500.0
# 1             Casa       Jardim Botânico        2   100   7000.0         0.0
# 2      Apartamento                Centro        1    15    800.0       390.0
# 3      Apartamento          Higienópolis        1    48    800.0       230.0
# 4      Apartamento              Cachambi        2    50   1300.0       301.0
# ...            ...                   ...      ...   ...      ...         ...
# 21662  Apartamento                 Méier        2    70    900.0       490.0
# 21663    Quitinete                Centro        0    27    800.0       350.0
# 21664  Apartamento           Jacarepaguá        3    78   1800.0       800.0
# 21665  Apartamento  São Francisco Xavier        2    48   1400.0       509.0
# 21666  Apartamento                Leblon        2    70   3000.0       760.0
#
#        Valor Bruto
# 0           2200.0
# 1           7000.0
# 2           1190.0
# 3           1030.0
# 4           1601.0
# ...            ...
# 21662       1390.0
# 21663       1150.0
# 21664       2600.0
# 21665       1909.0
# 21666       3760.0
#
# [21667 rows x 7 columns]

# %% [markdown]
# #### 2.4.2 Fazendo o cálculo do valor do metro quadrado
#
# O valor por metro quadrado é a divisão do valor bruto pela área, que já está em metros quadrados, então, não é necessário fazer conservação de unidades.

# %%
dados_residenciais['Valor / m^2'] = dados_residenciais['Valor Bruto'] / dados_residenciais['Area']
dados_residenciais
# Out:
#               Tipo                Bairro  Quartos  Area  Aluguel  Condominio  \
# 0        Quitinete            Copacabana        1    40   1700.0       500.0
# 1             Casa       Jardim Botânico        2   100   7000.0         0.0
# 2      Apartamento                Centro        1    15    800.0       390.0
# 3      Apartamento          Higienópolis        1    48    800.0       230.0
# 4      Apartamento              Cachambi        2    50   1300.0       301.0
# ...            ...                   ...      ...   ...      ...         ...
# 21662  Apartamento                 Méier        2    70    900.0       490.0
# 21663    Quitinete                Centro        0    27    800.0       350.0
# 21664  Apartamento           Jacarepaguá        3    78   1800.0       800.0
# 21665  Apartamento  São Francisco Xavier        2    48   1400.0       509.0
# 21666  Apartamento                Leblon        2    70   3000.0       760.0
#
#        Valor Bruto  Valor / m^2
# 0           2200.0    55.000000
# 1           7000.0    70.000000
# 2           1190.0    79.333333
# 3           1030.0    21.458333
# 4           1601.0    32.020000
# ...            ...          ...
# 21662       1390.0    19.857143
# 21663       1150.0    42.592593
# 21664       2600.0    33.333333
# 21665       1909.0    39.770833
# 21666       3760.0    53.714286
#
# [21667 rows x 8 columns]

# %%
# Vamos deixar menos casas decimais para o "Valor por m^2"
dados_residenciais['Valor / m^2'] = dados_residenciais['Valor / m^2'].round(1)
dados_residenciais
# Out:
#               Tipo                Bairro  Quartos  Area  Aluguel  Condominio  \
# 0        Quitinete            Copacabana        1    40   1700.0       500.0
# 1             Casa       Jardim Botânico        2   100   7000.0         0.0
# 2      Apartamento                Centro        1    15    800.0       390.0
# 3      Apartamento          Higienópolis        1    48    800.0       230.0
# 4      Apartamento              Cachambi        2    50   1300.0       301.0
# ...            ...                   ...      ...   ...      ...         ...
# 21662  Apartamento                 Méier        2    70    900.0       490.0
# 21663    Quitinete                Centro        0    27    800.0       350.0
# 21664  Apartamento           Jacarepaguá        3    78   1800.0       800.0
# 21665  Apartamento  São Francisco Xavier        2    48   1400.0       509.0
# 21666  Apartamento                Leblon        2    70   3000.0       760.0
#
#        Valor Bruto  Valor / m^2
# 0           2200.0         55.0
# 1           7000.0         70.0
# 2           1190.0         79.3
# 3           1030.0         21.5
# 4           1601.0         32.0
# ...            ...          ...
# 21662       1390.0         19.9
# 21663       1150.0         42.6
# 21664       2600.0         33.3
# 21665       1909.0         39.8
# 21666       3760.0         53.7
#
# [21667 rows x 8 columns]

# %%
dados_residenciais.to_csv('Arquivos gerados no código/Base de dados de imóveis residenciais - Versão final.csv', sep = ';', index = False)
# Exportando a nova base de dados, que contem apenas os imóveis residenciais,
# agora tratados e com as novas variáveis.

# %% [markdown]
# #### 2.4.3 Contando a quantidade de imóveis com certas quantidades de quartos
#
# Aparentemente, tem alguns casos com 0 quartos, vamos começar verificando quais casos isso acontece e depois descobrir quantos imóveis tem em cada conjunto de interesse: até 2 quartos, de 3 a 4, de 5 a 6 e 7 ou mais

# %%
zero = [0]

# %%
selecao = dados_residenciais['Quartos'].isin(zero)
selecao
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21662    False
# 21663     True
# 21664    False
# 21665    False
# 21666    False
# Name: Quartos, Length: 21667, dtype: bool

# %%
dados_residenciais[selecao]
# Out:
#               Tipo      Bairro  Quartos  Area  Aluguel  Condominio  \
# 68       Quitinete      Centro        0    30    800.0       505.0
# 75       Quitinete    Flamengo        0    28   1000.0       581.0
# 117      Quitinete      Catete        0    20    700.0       500.0
# 143      Quitinete      Centro        0    28    700.0       400.0
# 911      Quitinete  Copacabana        0    17   1000.0       520.0
# ...            ...         ...      ...   ...      ...         ...
# 20288    Quitinete      Catete        0    22   1100.0       471.0
# 20624    Quitinete      Catete        0    24   1100.0       268.0
# 20766  Apartamento  Copacabana        0    34   1200.0       480.0
# 20921    Quitinete    Botafogo        0    24   1200.0       450.0
# 21663    Quitinete      Centro        0    27    800.0       350.0
#
#        Valor Bruto  Valor / m^2
# 68          1305.0         43.5
# 75          1581.0         56.5
# 117         1200.0         60.0
# 143         1100.0         39.3
# 911         1520.0         89.4
# ...            ...          ...
# 20288       1571.0         71.4
# 20624       1368.0         57.0
# 20766       1680.0         49.4
# 20921       1650.0         68.8
# 21663       1150.0         42.6
#
# [154 rows x 8 columns]

# %%
selecao1 = (dados_residenciais['Tipo'] == 'Quitinete') & (dados_residenciais['Quartos'] == 0)
dados_residenciais[selecao1]
# Out:
#             Tipo       Bairro  Quartos  Area  Aluguel  Condominio  \
# 68     Quitinete       Centro        0    30    800.0       505.0
# 75     Quitinete     Flamengo        0    28   1000.0       581.0
# 117    Quitinete       Catete        0    20    700.0       500.0
# 143    Quitinete       Centro        0    28    700.0       400.0
# 911    Quitinete   Copacabana        0    17   1000.0       520.0
# ...          ...          ...      ...   ...      ...         ...
# 20239  Quitinete  Laranjeiras        0    28   1000.0       440.0
# 20288  Quitinete       Catete        0    22   1100.0       471.0
# 20624  Quitinete       Catete        0    24   1100.0       268.0
# 20921  Quitinete     Botafogo        0    24   1200.0       450.0
# 21663  Quitinete       Centro        0    27    800.0       350.0
#
#        Valor Bruto  Valor / m^2
# 68          1305.0         43.5
# 75          1581.0         56.5
# 117         1200.0         60.0
# 143         1100.0         39.3
# 911         1520.0         89.4
# ...            ...          ...
# 20239       1440.0         51.4
# 20288       1571.0         71.4
# 20624       1368.0         57.0
# 20921       1650.0         68.8
# 21663       1150.0         42.6
#
# [134 rows x 8 columns]

# %%
selecao2 = (dados_residenciais['Tipo'] == 'Quitinete') & (dados_residenciais['Quartos'] > 0)
dados_residenciais[selecao2]
# Out:
#             Tipo      Bairro  Quartos  Area  Aluguel  Condominio  Valor Bruto  \
# 0      Quitinete  Copacabana        1    40   1700.0       500.0       2200.0
# 8      Quitinete  Copacabana        1    27   1800.0       501.0       2301.0
# 25     Quitinete  Copacabana        1    27   1300.0       380.0       1680.0
# 83     Quitinete  Copacabana        1    29   1200.0       460.0       1660.0
# 98     Quitinete      Glória        1    16   1400.0       300.0       1700.0
# ...          ...         ...      ...   ...      ...         ...          ...
# 21523  Quitinete  Copacabana        1    32   1600.0       692.0       2292.0
# 21528  Quitinete      Glória        1    10    400.0       107.0        507.0
# 21569  Quitinete    Flamengo        1    23    900.0       605.0       1505.0
# 21589  Quitinete      Centro        1    24   1100.0       323.0       1423.0
# 21656  Quitinete  Copacabana        1    22   1500.0       286.0       1786.0
#
#        Valor / m^2
# 0             55.0
# 8             85.2
# 25            62.2
# 83            57.2
# 98           106.2
# ...            ...
# 21523         71.6
# 21528         50.7
# 21569         65.4
# 21589         59.3
# 21656         81.2
#
# [638 rows x 8 columns]

# %%
mensagem = f'''
Há {dados_residenciais[selecao].shape[0]} imóveis residenciais sem quartos,  
sendo {dados_residenciais[selecao1].shape[0]} quitinetes. Ao mesmo tempo, há 
{dados_residenciais[selecao2].shape[0]} quitinetes marcados com 1 quarto ou 
mais.
'''
print(mensagem)
# Out:
# Há 154 imóveis residenciais sem quartos,
# sendo 134 quitinetes. Ao mesmo tempo, há
# 638 quitinetes marcados com 1 quarto ou
# mais.

# %%
classes = [0, 2, 4, 6, 100]

# %%
quartos = pd.cut(dados_residenciais.Quartos, classes)
quartos
# Dessa maneira, não incliu o valor zero, para incluir, precisa colocar o "include_lowest= True".
# Out:
# 0        (0.0, 2.0]
# 1        (0.0, 2.0]
# 2        (0.0, 2.0]
# 3        (0.0, 2.0]
# 4        (0.0, 2.0]
#             ...
# 21662    (0.0, 2.0]
# 21663           NaN
# 21664    (2.0, 4.0]
# 21665    (0.0, 2.0]
# 21666    (0.0, 2.0]
# Name: Quartos, Length: 21667, dtype: category
# Categories (4, interval[int64, right]): [(0, 2] < (2, 4] < (4, 6] < (6, 100]]

# %%
# Incluindo os imóveis com zeros quartos.
quartos = pd.cut(dados_residenciais.Quartos, classes, include_lowest= True)
quartos
# Out:
# 0        (-0.001, 2.0]
# 1        (-0.001, 2.0]
# 2        (-0.001, 2.0]
# 3        (-0.001, 2.0]
# 4        (-0.001, 2.0]
#              ...
# 21662    (-0.001, 2.0]
# 21663    (-0.001, 2.0]
# 21664       (2.0, 4.0]
# 21665    (-0.001, 2.0]
# 21666    (-0.001, 2.0]
# Name: Quartos, Length: 21667, dtype: category
# Categories (4, interval[float64, right]): [(-0.001, 2.0] < (2.0, 4.0] < (4.0, 6.0] < (6.0, 100.0]]

# %%
# Imprimindo a quantidade de imóveis em cada intervalo de interesse.
pd.value_counts(quartos)
# Out:
# (-0.001, 2.0]    11312
# (2.0, 4.0]        9646
# (4.0, 6.0]         660
# (6.0, 100.0]        49
# Name: Quartos, dtype: int64

# %%
# Renomeando os rótulos.
labels = ['Até 2 quartos:', '3 e 4 quartos:', '5 e 6  quartos:', '7 quartos ou mais:']
quartos = pd.cut(dados_residenciais.Quartos, classes, labels = labels, include_lowest= True)
pd.value_counts(quartos)
# Out:
# Até 2 quartos:        11312
# 3 e 4 quartos:         9646
# 5 e 6  quartos:         660
# 7 quartos ou mais:       49
# Name: Quartos, dtype: int64

# %% [markdown]
# #### 2.4.4 Fazendo o cálculo dos valores estatísticos descritivos
#
# Nesta seção serão calculados os valores estatísticos descritivos, como média, devio padrão e mediana, para cada bairro. Uma boa maneira para fazer essa análise é usando o groupby, que é uma maneira de armazenas um DataFrame por tipo de variável, muito útil para fazer tabelas e gráficos. Mas antes de fazer isso, começamos organizando todos os bairros.

# %%
list(dados_residenciais['Bairro'].drop_duplicates())
# Out:
# ['Copacabana',
#  'Jardim Botânico',
#  'Centro',
#  'Higienópolis',
#  'Cachambi',
#  'Grajaú',
#  'Lins de Vasconcelos',
#  'Freguesia (Jacarepaguá)',
#  'Barra da Tijuca',
#  'Tijuca',
#  'Olaria',
#  'Ipanema',
#  'Campo Grande',
#  'Botafogo',
#  'Recreio dos Bandeirantes',
#  'Leblon',
#  'Jardim Oceânico',
#  'Humaitá',
#  'Península',
#  'Méier',
#  'Vargem Pequena',
#  'Maracanã',
#  'Jacarepaguá',
#  'São Conrado',
#  'Vila Valqueire',
#  'Gávea',
#  'Cosme Velho',
#  'Bonsucesso',
#  'Todos os Santos',
#  'Laranjeiras',
#  'Itanhangá',
#  'Flamengo',
#  'Piedade',
#  'Lagoa',
#  'Catete',
#  'Jardim Carioca',
#  'Benfica',
#  'Glória',
#  'Praça Seca',
#  'Vila Isabel',
#  'Taquara',
#  'Engenho Novo',
#  'Engenho de Dentro',
#  'Pilares',
#  'Água Santa',
#  'São Cristóvão',
#  'Ilha do Governador',
#  'Jardim Sulacap',
#  'Oswaldo Cruz',
#  'Vila da Penha',
#  'Anil',
#  'Vargem Grande',
#  'Tanque',
#  'Vaz Lobo',
#  'Madureira',
#  'São Francisco Xavier',
#  'Pechincha',
#  'Leme',
#  'Irajá',
#  'Quintino Bocaiúva',
#  'Urca',
#  'Penha',
#  'Rio Comprido',
#  'Andaraí',
#  'Santa Teresa',
#  'Inhaúma',
#  'Marechal Hermes',
#  'Curicica',
#  'Santíssimo',
#  'Moneró',
#  'Camorim',
#  'Cascadura',
#  'Praia da Bandeira',
#  'Ramos',
#  'Saúde',
#  'Realengo',
#  'Fátima',
#  'Inhoaíba',
#  'Rocha',
#  'Jardim Guanabara',
#  'Jabour',
#  'Braz de Pina',
#  'Praça da Bandeira',
#  'Vila Kosmos',
#  'Vista Alegre',
#  'Encantado',
#  'Campinho',
#  'Guaratiba',
#  'Riachuelo',
#  'Bangu',
#  'Lapa',
#  'Catumbi',
#  'Penha Circular',
#  'Abolição',
#  'Tomás Coelho',
#  'Colégio',
#  'Pavuna',
#  'Santa Cruz',
#  'Joá',
#  'Alto da Boa Vista',
#  'Cidade Nova',
#  'Bento Ribeiro',
#  'Estácio',
#  'Jardim América',
#  'Cordovil',
#  'Caju',
#  'Pedra de Guaratiba',
#  'Padre Miguel',
#  'Paciência',
#  'Del Castilho',
#  'Arpoador',
#  'Sampaio',
#  'Anchieta',
#  'Icaraí',
#  'Senador Vasconcelos',
#  'Rocha Miranda',
#  'Gamboa',
#  'Maria da Graça',
#  'Barra de Guaratiba',
#  'Vicente de Carvalho',
#  'Paquetá',
#  'Largo do Machado',
#  'Parada de Lucas',
#  'Freguesia (Ilha do Governador)',
#  'Gardênia Azul',
#  'Portuguesa',
#  'Guadalupe',
#  'Parque Anchieta',
#  'Turiaçu',
#  'Pitangueiras',
#  'Vila Militar',
#  'Vidigal',
# Anil               2071.71      462.36      2534.07        24.87
# ...                    ...         ...          ...          ...
# Vila Valqueire     1769.58      276.88      2046.46        19.46
# Vila da Penha      1295.45      244.43      1539.89        22.00
# Vista Alegre       1114.38      210.06      1324.44        19.00
# Zumbi              2150.00     1050.00      3200.00        40.30
# Água Santa          861.11      269.44      1130.56        20.97
#
# [152 rows x 4 columns]

# %%
grupo_bairro['Aluguel'].describe().round(2)
# Out:
#                    count     mean      std     min     25%     50%     75%  \
# Bairro
# Abolição            15.0  1195.33   425.32   800.0   900.0  1180.0  1200.0
# Alto da Boa Vista    6.0  3966.67  5513.59   600.0  1150.0  1725.0  3275.0
# Anchieta             4.0   875.00   132.29   700.0   812.5   900.0   962.5
# Andaraí             97.0  1464.71   408.11   700.0  1200.0  1400.0  1650.0
# Anil                70.0  2071.71  1522.69   300.0  1100.0  1500.0  2712.5
# ...                  ...      ...      ...     ...     ...     ...     ...
# Vila Valqueire      48.0  1769.58  2203.01   800.0  1000.0  1250.0  1700.0
# Vila da Penha       99.0  1295.45   641.09   600.0   900.0  1200.0  1355.0
# Vista Alegre        16.0  1114.38   199.60   700.0  1012.5  1200.0  1225.0
# Zumbi                2.0  2150.00   777.82  1600.0  1875.0  2150.0  2425.0
# Água Santa           9.0   861.11   174.60   600.0   800.0   850.0   950.0
#
#                        max
# Bairro
# Abolição            2300.0
# Alto da Boa Vista  15000.0
# Anchieta            1000.0
# Andaraí             2950.0
# Anil                7000.0
# ...                    ...
# Vila Valqueire     16000.0
# Vila da Penha       4500.0
# Vista Alegre        1400.0
# Zumbi               2700.0
# Água Santa          1200.0
#
# [152 rows x 8 columns]

# %%
# Usando o "aggregate" é possível selecionar quais os valores de interesse,
# além de mudar os nomes das colunas.
grupo_bairro['Aluguel'].aggregate([
    'count', 'mean', 'std', 'median', 'min', 'max', 'sum'
    ]).round(2).rename(columns = {
    'count': 'Frequência',
    'mean': 'Média',
    'std': 'Desvio Padrão',
    'median': 'Mediana',
    'min': 'Mínimo', 
    'max': 'Máximo',
    'sum': 'Soma'
    })
# Out:
#                    Frequência    Média  Desvio Padrão  Mediana  Mínimo  \
# Bairro
# Abolição                   15  1195.33         425.32   1180.0   800.0
# Alto da Boa Vista           6  3966.67        5513.59   1725.0   600.0
# Anchieta                    4   875.00         132.29    900.0   700.0
# Andaraí                    97  1464.71         408.11   1400.0   700.0
# Anil                       70  2071.71        1522.69   1500.0   300.0
# ...                       ...      ...            ...      ...     ...
# Vila Valqueire             48  1769.58        2203.01   1250.0   800.0
# Vila da Penha              99  1295.45         641.09   1200.0   600.0
# Vista Alegre               16  1114.38         199.60   1200.0   700.0
# Zumbi                       2  2150.00         777.82   2150.0  1600.0
# Água Santa                  9   861.11         174.60    850.0   600.0
#
#                     Máximo      Soma
# Bairro
# Abolição            2300.0   17930.0
# Alto da Boa Vista  15000.0   23800.0
# Anchieta            1000.0    3500.0
# Andaraí             2950.0  142077.0
# Anil                7000.0  145020.0
# ...                    ...       ...
# Vila Valqueire     16000.0   84940.0
# Vila da Penha       4500.0  128250.0
# Vista Alegre        1400.0   17830.0
# Zumbi               2700.0    4300.0
# Água Santa          1200.0    7750.0
#
# [152 rows x 7 columns]

# %%
plt.rc('figure', figsize = (20, 10))

# %%
fig = grupo_bairro['Aluguel'].mean().plot.bar(color = 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %%
fig = grupo_bairro['Aluguel'].max().plot.bar(color = 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %%
fig = grupo_bairro['Aluguel'].std().plot.bar(color = 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %% [markdown]
# #### 2.4.5 Removendo os outliers
#
# Para remover os outliers, vamos usar o Box Plot, representado na imagem abaixo.
#
# <img src="Box-Plot.png" width=35%>
#
# - Q1: Valor referente ao primeiro quartil (25%).
# - Q3: Valor referente ao terceiro quartil (75%).
# - IIQ: Intervalo interquartílico, a variação entre o primeiro e o terceito quartil.
# - Limite inferior: representado pela expressão Q1 - 1.5 $\times$ IIQ, uma métrica para saber quais valores inferiores estão muito discrepantes, com relação aos outros.
# - Limite superior: representado pela expressão Q3 + 1.5 $\times$ IIQ, para retirar os valores superios muito discrepantes.

# %%
dados_residenciais.boxplot(['Aluguel'])
# Esse Box Plot não ficou simiar ao que é visualizado na representação acima 
# pois ainda está com os outliers, alguns dos valores muito destoantes.
# Out:
# <AxesSubplot: >

# %%
dados_residenciais.hist(['Aluguel'])
# Out:
# array([[<AxesSubplot: title={'center': 'Aluguel'}>]], dtype=object)

# %%
aluguel = dados_residenciais['Aluguel']
aluguel
# Out:
# 0        1700.0
# 1        7000.0
# 2         800.0
# 3         800.0
# 4        1300.0
#           ...
# 21662     900.0
# 21663     800.0
# 21664    1800.0
# 21665    1400.0
# 21666    3000.0
# Name: Aluguel, Length: 21667, dtype: float64

# %%
Q1 = aluguel.quantile(.25)
Q3 = aluguel.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
selecao = ((aluguel >= limite_inferior) & (aluguel <= limite_superior))
selecao
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 21662    True
# 21663    True
# 21664    True
# 21665    True
# 21666    True
# Name: Aluguel, Length: 21667, dtype: bool

# %%
dados_residenciais = dados_residenciais[selecao]
dados_residenciais
# Out:
#               Tipo                Bairro  Quartos  Area  Aluguel  Condominio  \
# 0        Quitinete            Copacabana        1    40   1700.0       500.0
# 1             Casa       Jardim Botânico        2   100   7000.0         0.0
# 2      Apartamento                Centro        1    15    800.0       390.0
# 3      Apartamento          Higienópolis        1    48    800.0       230.0
# 4      Apartamento              Cachambi        2    50   1300.0       301.0
# ...            ...                   ...      ...   ...      ...         ...
# 21662  Apartamento                 Méier        2    70    900.0       490.0
# 21663    Quitinete                Centro        0    27    800.0       350.0
# 21664  Apartamento           Jacarepaguá        3    78   1800.0       800.0
# 21665  Apartamento  São Francisco Xavier        2    48   1400.0       509.0
# 21666  Apartamento                Leblon        2    70   3000.0       760.0
#
#        Valor Bruto  Valor / m^2
# 0           2200.0         55.0
# 1           7000.0         70.0
# 2           1190.0         79.3
# 3           1030.0         21.5
# 4           1601.0         32.0
# ...            ...          ...
# 21662       1390.0         19.9
# 21663       1150.0         42.6
# 21664       2600.0         33.3
# 21665       1909.0         39.8
# 21666       3760.0         53.7
#
# [19687 rows x 8 columns]

# %%
dados_retirados = dados_residenciais[~selecao]
dados_retirados
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_10544\1208380491.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dados_retirados = dados_residenciais[~selecao]
#               Tipo                    Bairro  Quartos  Area  Aluguel  \
# 9      Apartamento   Freguesia (Jacarepaguá)        3    54    950.0
# 19     Apartamento                Copacabana        3   378  10000.0
# 39     Apartamento                     Méier        3    90   1550.0
# 41     Apartamento                  Botafogo        3   108   5950.0
# 54     Apartamento                     Gávea        2    70   2800.0
# ...            ...                       ...      ...   ...      ...
# 19641  Apartamento  Recreio dos Bandeirantes        4   230   7000.0
# 19651  Apartamento                    Leblon        2    90  10500.0
# 19661  Apartamento  Recreio dos Bandeirantes        3   100   2500.0
# 19668  Apartamento           Todos os Santos        3    54   1500.0
# 19672  Apartamento                Copacabana        2    70   4100.0
#
#        Condominio  Valor Bruto  Valor / m^2
# 9           300.0       1250.0         23.1
# 19         2150.0      12150.0         32.1
# 39          844.0       2394.0         26.6
# 41         1405.0       7355.0         68.1
# 54          680.0       3480.0         49.7
# ...           ...          ...          ...
# 19641      1490.0       8490.0         36.9
# 19651     23511.0      34011.0        377.9
# 19661       650.0       3150.0         31.5
# 19668       289.0       1789.0         33.1
# 19672       700.0       4800.0         68.6
#
# [1795 rows x 8 columns]

# %%
# Correção dos índices, similar ao que já foi feito anteriormentes.
dados_residenciais.index = range(dados_residenciais.shape[0])
dados_residenciais
# Out:
#               Tipo                Bairro  Quartos  Area  Aluguel  Condominio  \
# 0        Quitinete            Copacabana        1    40   1700.0       500.0
# 1             Casa       Jardim Botânico        2   100   7000.0         0.0
# 2      Apartamento                Centro        1    15    800.0       390.0
# 3      Apartamento          Higienópolis        1    48    800.0       230.0
# 4      Apartamento              Cachambi        2    50   1300.0       301.0
# ...            ...                   ...      ...   ...      ...         ...
# 19682  Apartamento                 Méier        2    70    900.0       490.0
# 19683    Quitinete                Centro        0    27    800.0       350.0
# 19684  Apartamento           Jacarepaguá        3    78   1800.0       800.0
# 19685  Apartamento  São Francisco Xavier        2    48   1400.0       509.0
# 19686  Apartamento                Leblon        2    70   3000.0       760.0
#
#        Valor Bruto  Valor / m^2
# 0           2200.0         55.0
# 1           7000.0         70.0
# 2           1190.0         79.3
# 3           1030.0         21.5
# 4           1601.0         32.0
# ...            ...          ...
# 19682       1390.0         19.9
# 19683       1150.0         42.6
# 19684       2600.0         33.3
# 19685       1909.0         39.8
# 19686       3760.0         53.7
#
# [19687 rows x 8 columns]

# %%
dados_residenciais.boxplot(['Aluguel'])
# Após a exclusão dos dados, o Box Plot ainda indica
# alguns valores como sendo outliers. Isso aconece pois
# os dados foram atualizados. Entretando, agora não 
# está mais na casa dos milhões, como estava no gráfico 
# passado, agora está na casa dos R$10.000,00, que são
# valores prováveis de aluguel. Nesse caso, vale a pena
# fazer uma análise com valores inferiores e superiores? Mas como?
# Out:
# <AxesSubplot: >

# %%
dados_residenciais.hist(['Aluguel'])
# Out:
# array([[<AxesSubplot: title={'center': 'Aluguel'}>]], dtype=object)
